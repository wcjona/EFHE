# %% [markdown]
# This program produces a Bi-CNN + LSTM model for prediciting whether a sequence is an EF hand

# %%
from __future__ import print_function
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Reshape
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Convolution1D, MaxPooling1D
import _pickle as cPickle
from sklearn.model_selection import train_test_split

# %%
# Converts sequence to vector 
def trans(str):
    a = []
    dic = {'A':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'H':7, 'I':8, 'K':9, 'L':10, 'M':11, 'N':12, 'P':13, 'Q':14, 'R':15, 'S':16, 'T':17, 'V':18, 'W':19, 'Y':20, 'X':21}
    for i in range(len(str)):
        a.append(dic.get(str[i]))
    return a

# %%
# Converts dataset into list containing sequence and it's label
def createTrainData(str1):
    sequence_num = []
    label_num = []
    for line in open(str1):
        label, sequence = line.split(",")
        # sequence = sequence.strip(' \t\r\n');
        sequence_num.append(trans(sequence))
        # label = label.strip(' \t\r\n');
        label_num.append(int(label))

    return sequence_num,label_num

# %%
# Converting dataset into x and y data
a,b=createTrainData("efHandData_neg_pos_interleukins.csv")
t = (a, b)
cPickle.dump(t,open("data.pkl","wb"))

# %%
# Splits training data and test data
def createTrainTestData(str_path, nb_words=None, skip_top=0,
              maxlen=None, test_split=0.25, seed=69420,
              start_char=1, oov_char=2, index_from=3):
    X,labels = cPickle.load(open(str_path, "rb"))

    for x in X:
      del x[-1]
      del x[-1]
    np.random.seed(seed) # for reproducibility
    np.random.shuffle(X)
    np.random.seed(seed)
    np.random.shuffle(labels)

    if maxlen:
        new_X = []
        new_labels = []
        for x, y in zip(X, labels):
            if len(x) < maxlen:
                new_X.append(x)
                new_labels.append(y)
        X = new_X
        labels = new_labels
    if not nb_words:
        nb_words = max([max(x) for x in X])

    X_train = np.array(X[:int(len(X) * (1 - test_split))])
    y_train = np.array(labels[:int(len(X) * (1 - test_split))])

    X_test = np.array(X[int(len(X) * (1 - test_split)):])
    y_test = np.array(labels[int(len(X) * (1 - test_split)):])
    
    return (X_train, y_train), (X_test, y_test)

# %%
# Embedding
max_features = 23
maxlen = 12
embedding_size = 256

# Convolution
nb_filter = 10
pool_length = 2

# LSTM
lstm_output_size = 12

# Training
batch_size = 128
nb_epoch = 150

# %%
# Creates training dataset
(X_train, y_train), (X_test, y_test) = createTrainTestData("data.pkl",nb_words=max_features, test_split=0.2)
print(X_train)
print(len(X_train), 'train sequences')
print(len(X_test), 'test sequences')
# Out:
# Loading data...
# [list([3, 20, 5, 6, 9, 10, 4, 13, 9, 8, 16])
#  list([3, 15, 11, 11, 16, 20, 10, 16, 16])
#  list([3, 17, 3, 9, 16, 6, 17, 8, 17, 20, 4]) ...
#  list([3, 3, 5, 18, 11, 16, 20, 10, 5, 1, 14])
#  list([3, 17, 12, 9, 16, 6, 17, 10, 3, 8, 7])
#  list([3, 18, 18, 16, 10, 18, 14, 7, 20, 18, 1, 16])]
# 3445 train sequences
# 862 test sequences

# %%
# Converts the list of str to a number
def listToNum(data):
  new = []
  for x in data: 
    temp = ''.join(map(str,x))
    temp = int(temp)
    new.append(temp)
  return new

# %%
# Pre processing data into correct shape:
X_train = sequence.pad_sequences(X_train, maxlen=maxlen)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)

# Implementing Embedding Layer
model = Sequential()
model.add(Embedding(max_features, embedding_size, input_length=maxlen))

# Adding Bi-CNN Layers
model.add(Dropout(0.5))
model.add(Convolution1D(activation='relu',filters=nb_filter, kernel_size=1))
model.add(MaxPooling1D(pool_size=pool_length, padding='same'))

model.add(Convolution1D(activation='relu',filters=nb_filter, kernel_size=1))
model.add(MaxPooling1D(pool_size=pool_length, padding='same'))

# Adding LSTM Layer
model.add(LSTM(lstm_output_size))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# Compiling model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Training Model
model.fit(X_train, y_train, batch_size=batch_size, epochs=nb_epoch,
          validation_data=(X_test, y_test))
# Out:
# Pad sequences (samples x time)
# X_train shape: (3445, 12)
# X_test shape: (862, 12)
# Build model...
# Train...
# Epoch 1/150
# 27/27 [==============================] - 4s 30ms/step - loss: 0.6833 - accuracy: 0.6810 - val_loss: 0.6646 - val_accuracy: 0.7807
# Epoch 2/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.6068 - accuracy: 0.8430 - val_loss: 0.5171 - val_accuracy: 0.8561
# Epoch 3/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.3897 - accuracy: 0.8958 - val_loss: 0.2716 - val_accuracy: 0.9049
# Epoch 4/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.2224 - accuracy: 0.9234 - val_loss: 0.1996 - val_accuracy: 0.9234
# Epoch 5/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1843 - accuracy: 0.9382 - val_loss: 0.1823 - val_accuracy: 0.9350
# Epoch 6/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1703 - accuracy: 0.9408 - val_loss: 0.1711 - val_accuracy: 0.9432
# Epoch 7/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1594 - accuracy: 0.9431 - val_loss: 0.1643 - val_accuracy: 0.9420
# Epoch 8/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1524 - accuracy: 0.9440 - val_loss: 0.1616 - val_accuracy: 0.9443
# Epoch 9/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1480 - accuracy: 0.9466 - val_loss: 0.1548 - val_accuracy: 0.9478
# Epoch 10/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1429 - accuracy: 0.9483 - val_loss: 0.1517 - val_accuracy: 0.9432
# Epoch 11/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1394 - accuracy: 0.9501 - val_loss: 0.1468 - val_accuracy: 0.9420
# Epoch 12/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1354 - accuracy: 0.9492 - val_loss: 0.1426 - val_accuracy: 0.9443
# Epoch 13/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1285 - accuracy: 0.9527 - val_loss: 0.1368 - val_accuracy: 0.9466
# Epoch 14/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1289 - accuracy: 0.9533 - val_loss: 0.1338 - val_accuracy: 0.9548
# Epoch 15/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1241 - accuracy: 0.9553 - val_loss: 0.1328 - val_accuracy: 0.9548
# Epoch 16/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1218 - accuracy: 0.9533 - val_loss: 0.1284 - val_accuracy: 0.9571
# Epoch 17/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1202 - accuracy: 0.9550 - val_loss: 0.1271 - val_accuracy: 0.9582
# Epoch 18/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1185 - accuracy: 0.9565 - val_loss: 0.1246 - val_accuracy: 0.9594
# Epoch 19/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1164 - accuracy: 0.9579 - val_loss: 0.1262 - val_accuracy: 0.9559
# Epoch 20/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1147 - accuracy: 0.9585 - val_loss: 0.1227 - val_accuracy: 0.9606
# Epoch 21/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1133 - accuracy: 0.9599 - val_loss: 0.1222 - val_accuracy: 0.9617
# Epoch 22/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1095 - accuracy: 0.9605 - val_loss: 0.1273 - val_accuracy: 0.9559
# Epoch 23/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1109 - accuracy: 0.9602 - val_loss: 0.1197 - val_accuracy: 0.9617
# Epoch 24/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1094 - accuracy: 0.9585 - val_loss: 0.1167 - val_accuracy: 0.9606
# Epoch 25/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1074 - accuracy: 0.9611 - val_loss: 0.1198 - val_accuracy: 0.9594
# Epoch 26/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.1037 - accuracy: 0.9640 - val_loss: 0.1161 - val_accuracy: 0.9606
# Epoch 27/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.1020 - accuracy: 0.9657 - val_loss: 0.1142 - val_accuracy: 0.9606
# Epoch 28/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1016 - accuracy: 0.9623 - val_loss: 0.1125 - val_accuracy: 0.9629
# Epoch 29/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0964 - accuracy: 0.9652 - val_loss: 0.1114 - val_accuracy: 0.9629
# Epoch 30/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0980 - accuracy: 0.9652 - val_loss: 0.1097 - val_accuracy: 0.9594
# Epoch 31/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.1001 - accuracy: 0.9655 - val_loss: 0.1109 - val_accuracy: 0.9571
# Epoch 32/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0931 - accuracy: 0.9669 - val_loss: 0.1069 - val_accuracy: 0.9582
# Epoch 33/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0932 - accuracy: 0.9669 - val_loss: 0.1078 - val_accuracy: 0.9617
# Epoch 34/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0932 - accuracy: 0.9649 - val_loss: 0.1067 - val_accuracy: 0.9582
# Epoch 35/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0899 - accuracy: 0.9669 - val_loss: 0.1059 - val_accuracy: 0.9594
# Epoch 36/150
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0901 - accuracy: 0.9689 - val_loss: 0.1050 - val_accuracy: 0.9594
# Epoch 37/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0872 - accuracy: 0.9689 - val_loss: 0.1048 - val_accuracy: 0.9606
# Epoch 38/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0839 - accuracy: 0.9704 - val_loss: 0.1036 - val_accuracy: 0.9594
# Epoch 39/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.1064 - val_accuracy: 0.9582
# Epoch 40/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0828 - accuracy: 0.9689 - val_loss: 0.1016 - val_accuracy: 0.9652
# Epoch 41/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0885 - accuracy: 0.9660 - val_loss: 0.1106 - val_accuracy: 0.9617
# Epoch 42/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0844 - accuracy: 0.9707 - val_loss: 0.0994 - val_accuracy: 0.9652
# Epoch 43/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0773 - accuracy: 0.9716 - val_loss: 0.1042 - val_accuracy: 0.9582
# Epoch 44/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0770 - accuracy: 0.9713 - val_loss: 0.0981 - val_accuracy: 0.9617
# Epoch 45/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0763 - accuracy: 0.9710 - val_loss: 0.1052 - val_accuracy: 0.9652
# Epoch 46/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0758 - accuracy: 0.9710 - val_loss: 0.0967 - val_accuracy: 0.9664
# Epoch 47/150
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0714 - accuracy: 0.9742 - val_loss: 0.0978 - val_accuracy: 0.9606
# Epoch 48/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0745 - accuracy: 0.9736 - val_loss: 0.0983 - val_accuracy: 0.9571
# Epoch 49/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0720 - accuracy: 0.9733 - val_loss: 0.0933 - val_accuracy: 0.9652
# Epoch 50/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0686 - accuracy: 0.9742 - val_loss: 0.0930 - val_accuracy: 0.9629
# Epoch 51/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0692 - accuracy: 0.9762 - val_loss: 0.0916 - val_accuracy: 0.9664
# Epoch 52/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0688 - accuracy: 0.9759 - val_loss: 0.0927 - val_accuracy: 0.9710
# Epoch 53/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0660 - accuracy: 0.9753 - val_loss: 0.0907 - val_accuracy: 0.9722
# Epoch 54/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0688 - accuracy: 0.9747 - val_loss: 0.0897 - val_accuracy: 0.9640
# Epoch 55/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0616 - accuracy: 0.9794 - val_loss: 0.0868 - val_accuracy: 0.9698
# Epoch 56/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0633 - accuracy: 0.9785 - val_loss: 0.0875 - val_accuracy: 0.9640
# Epoch 57/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0620 - accuracy: 0.9797 - val_loss: 0.0863 - val_accuracy: 0.9733
# Epoch 58/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0636 - accuracy: 0.9779 - val_loss: 0.0836 - val_accuracy: 0.9710
# Epoch 59/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0643 - accuracy: 0.9762 - val_loss: 0.0836 - val_accuracy: 0.9722
# Epoch 60/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 0.0876 - val_accuracy: 0.9745
# Epoch 61/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0601 - accuracy: 0.9785 - val_loss: 0.0837 - val_accuracy: 0.9756
# Epoch 62/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0575 - accuracy: 0.9811 - val_loss: 0.0841 - val_accuracy: 0.9710
# Epoch 63/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0587 - accuracy: 0.9803 - val_loss: 0.0808 - val_accuracy: 0.9745
# Epoch 64/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0576 - accuracy: 0.9794 - val_loss: 0.0798 - val_accuracy: 0.9733
# Epoch 65/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0576 - accuracy: 0.9794 - val_loss: 0.0848 - val_accuracy: 0.9664
# Epoch 66/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0554 - accuracy: 0.9829 - val_loss: 0.0787 - val_accuracy: 0.9722
# Epoch 67/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0533 - accuracy: 0.9837 - val_loss: 0.0815 - val_accuracy: 0.9698
# Epoch 68/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0533 - accuracy: 0.9820 - val_loss: 0.0814 - val_accuracy: 0.9710
# Epoch 69/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0569 - accuracy: 0.9829 - val_loss: 0.0789 - val_accuracy: 0.9722
# Epoch 70/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0554 - accuracy: 0.9829 - val_loss: 0.0776 - val_accuracy: 0.9780
# Epoch 71/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0516 - accuracy: 0.9829 - val_loss: 0.0755 - val_accuracy: 0.9722
# Epoch 72/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0511 - accuracy: 0.9817 - val_loss: 0.0756 - val_accuracy: 0.9710
# Epoch 73/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0500 - accuracy: 0.9835 - val_loss: 0.0744 - val_accuracy: 0.9745
# Epoch 74/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0484 - accuracy: 0.9843 - val_loss: 0.0743 - val_accuracy: 0.9733
# Epoch 75/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0492 - accuracy: 0.9837 - val_loss: 0.0796 - val_accuracy: 0.9698
# Epoch 76/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.0746 - val_accuracy: 0.9768
# Epoch 77/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0490 - accuracy: 0.9852 - val_loss: 0.0732 - val_accuracy: 0.9745
# Epoch 78/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0448 - accuracy: 0.9872 - val_loss: 0.0770 - val_accuracy: 0.9745
# Epoch 79/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0466 - accuracy: 0.9861 - val_loss: 0.0856 - val_accuracy: 0.9675
# Epoch 80/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0482 - accuracy: 0.9832 - val_loss: 0.0755 - val_accuracy: 0.9745
# Epoch 81/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0436 - accuracy: 0.9872 - val_loss: 0.0739 - val_accuracy: 0.9756
# Epoch 82/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0446 - accuracy: 0.9866 - val_loss: 0.0725 - val_accuracy: 0.9768
# Epoch 83/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0459 - accuracy: 0.9817 - val_loss: 0.0773 - val_accuracy: 0.9756
# Epoch 84/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0418 - accuracy: 0.9849 - val_loss: 0.0727 - val_accuracy: 0.9722
# Epoch 85/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0443 - accuracy: 0.9843 - val_loss: 0.0749 - val_accuracy: 0.9733
# Epoch 86/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0417 - accuracy: 0.9832 - val_loss: 0.0793 - val_accuracy: 0.9698
# Epoch 87/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0419 - accuracy: 0.9869 - val_loss: 0.0761 - val_accuracy: 0.9756
# Epoch 88/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0751 - val_accuracy: 0.9756
# Epoch 89/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0407 - accuracy: 0.9866 - val_loss: 0.0728 - val_accuracy: 0.9780
# Epoch 90/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0418 - accuracy: 0.9869 - val_loss: 0.0718 - val_accuracy: 0.9756
# Epoch 91/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0400 - accuracy: 0.9878 - val_loss: 0.0763 - val_accuracy: 0.9733
# Epoch 92/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0395 - accuracy: 0.9869 - val_loss: 0.0750 - val_accuracy: 0.9780
# Epoch 93/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0399 - accuracy: 0.9872 - val_loss: 0.0688 - val_accuracy: 0.9791
# Epoch 94/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0359 - accuracy: 0.9896 - val_loss: 0.0734 - val_accuracy: 0.9745
# Epoch 95/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0374 - accuracy: 0.9901 - val_loss: 0.0712 - val_accuracy: 0.9768
# Epoch 96/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0372 - accuracy: 0.9896 - val_loss: 0.0724 - val_accuracy: 0.9768
# Epoch 97/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0397 - accuracy: 0.9858 - val_loss: 0.0726 - val_accuracy: 0.9756
# Epoch 98/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0361 - accuracy: 0.9881 - val_loss: 0.0699 - val_accuracy: 0.9756
# Epoch 99/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0369 - accuracy: 0.9893 - val_loss: 0.0664 - val_accuracy: 0.9803
# Epoch 100/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0338 - accuracy: 0.9901 - val_loss: 0.0740 - val_accuracy: 0.9756
# Epoch 101/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0371 - accuracy: 0.9890 - val_loss: 0.0708 - val_accuracy: 0.9803
# Epoch 102/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0365 - accuracy: 0.9887 - val_loss: 0.0709 - val_accuracy: 0.9745
# Epoch 103/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0341 - accuracy: 0.9904 - val_loss: 0.0728 - val_accuracy: 0.9733
# Epoch 104/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0341 - accuracy: 0.9904 - val_loss: 0.0730 - val_accuracy: 0.9756
# Epoch 105/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0333 - accuracy: 0.9904 - val_loss: 0.0689 - val_accuracy: 0.9780
# Epoch 106/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.0703 - val_accuracy: 0.9803
# Epoch 107/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0310 - accuracy: 0.9916 - val_loss: 0.0723 - val_accuracy: 0.9768
# Epoch 108/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0311 - accuracy: 0.9913 - val_loss: 0.0696 - val_accuracy: 0.9780
# Epoch 109/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0311 - accuracy: 0.9910 - val_loss: 0.0700 - val_accuracy: 0.9791
# Epoch 110/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0314 - accuracy: 0.9907 - val_loss: 0.0653 - val_accuracy: 0.9803
# Epoch 111/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0326 - accuracy: 0.9904 - val_loss: 0.0676 - val_accuracy: 0.9768
# Epoch 112/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0310 - accuracy: 0.9904 - val_loss: 0.0728 - val_accuracy: 0.9745
# Epoch 113/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0303 - accuracy: 0.9907 - val_loss: 0.0707 - val_accuracy: 0.9733
# Epoch 114/150
# 27/27 [==============================] - 1s 18ms/step - loss: 0.0297 - accuracy: 0.9910 - val_loss: 0.0694 - val_accuracy: 0.9791
# Epoch 115/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0287 - accuracy: 0.9919 - val_loss: 0.0696 - val_accuracy: 0.9791
# Epoch 116/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0269 - accuracy: 0.9927 - val_loss: 0.0676 - val_accuracy: 0.9791
# Epoch 117/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 0.0706 - val_accuracy: 0.9780
# Epoch 118/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0320 - accuracy: 0.9898 - val_loss: 0.0671 - val_accuracy: 0.9745
# Epoch 119/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.0736 - val_accuracy: 0.9722
# Epoch 120/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0279 - accuracy: 0.9922 - val_loss: 0.0670 - val_accuracy: 0.9768
# Epoch 121/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0262 - accuracy: 0.9919 - val_loss: 0.0757 - val_accuracy: 0.9756
# Epoch 122/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0275 - accuracy: 0.9927 - val_loss: 0.0717 - val_accuracy: 0.9768
# Epoch 123/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 0.0718 - val_accuracy: 0.9780
# Epoch 124/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0273 - accuracy: 0.9930 - val_loss: 0.0698 - val_accuracy: 0.9780
# Epoch 125/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0258 - accuracy: 0.9922 - val_loss: 0.0668 - val_accuracy: 0.9780
# Epoch 126/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0259 - accuracy: 0.9919 - val_loss: 0.0753 - val_accuracy: 0.9745
# Epoch 127/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0281 - accuracy: 0.9919 - val_loss: 0.0701 - val_accuracy: 0.9791
# Epoch 128/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0256 - accuracy: 0.9939 - val_loss: 0.0762 - val_accuracy: 0.9733
# Epoch 129/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0235 - accuracy: 0.9942 - val_loss: 0.0690 - val_accuracy: 0.9791
# Epoch 130/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0245 - accuracy: 0.9945 - val_loss: 0.0638 - val_accuracy: 0.9803
# Epoch 131/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.0689 - val_accuracy: 0.9756
# Epoch 132/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.0750 - val_accuracy: 0.9768
# Epoch 133/150
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.0709 - val_accuracy: 0.9768
# Epoch 134/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 0.0677 - val_accuracy: 0.9803
# Epoch 135/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.0657 - val_accuracy: 0.9803
# Epoch 136/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0231 - accuracy: 0.9936 - val_loss: 0.0729 - val_accuracy: 0.9756
# Epoch 137/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0239 - accuracy: 0.9936 - val_loss: 0.0699 - val_accuracy: 0.9803
# Epoch 138/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.0804 - val_accuracy: 0.9722
# Epoch 139/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0236 - accuracy: 0.9939 - val_loss: 0.0680 - val_accuracy: 0.9791
# Epoch 140/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.0690 - val_accuracy: 0.9756
# Epoch 141/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0219 - accuracy: 0.9948 - val_loss: 0.0662 - val_accuracy: 0.9803
# Epoch 142/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0215 - accuracy: 0.9936 - val_loss: 0.0649 - val_accuracy: 0.9803
# Epoch 143/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0213 - accuracy: 0.9951 - val_loss: 0.0676 - val_accuracy: 0.9768
# Epoch 144/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0185 - accuracy: 0.9968 - val_loss: 0.0684 - val_accuracy: 0.9780
# Epoch 145/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0223 - accuracy: 0.9945 - val_loss: 0.0647 - val_accuracy: 0.9791
# Epoch 146/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0198 - accuracy: 0.9954 - val_loss: 0.0686 - val_accuracy: 0.9768
# Epoch 147/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.0639 - val_accuracy: 0.9803
# Epoch 148/150
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 0.0684 - val_accuracy: 0.9803
# Epoch 149/150
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.0673 - val_accuracy: 0.9780
# Epoch 150/150
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0192 - accuracy: 0.9951 - val_loss: 0.0680 - val_accuracy: 0.9791

# %%
# Saving Model
model.save("epoch150.h5") 
# Evaluating acurracy of model
score, acc = model.evaluate(X_test, y_test, batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9791
# Test score: 0.06801965832710266
# Test accuracy: 0.9791183471679688
